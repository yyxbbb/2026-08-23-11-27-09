# %% [markdown]
# # 第一个单元设为 Markdown，写 # 第12天练习：Jupyter 试水，运行它（应渲染成标题）。
# # 新建 代码 单元，导入 numpy 和 pyplot，画出 x 在 0~10 取 50 个点的正弦曲线并显示。
# # 把它保存为 day12_practice.ipynb。

# %% [markdown]
# # 第12天练习：Jupyter 试水

# %%
import numpy as np, matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 50)
y = np.sin(x)
plt.plot(x, y)
plt.title('正弦曲线')
plt.show()
